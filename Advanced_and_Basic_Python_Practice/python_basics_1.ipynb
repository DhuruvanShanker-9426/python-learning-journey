# %%
print("Hello anime")
# Out:
# Hello anime

# %%
f_name="dhuruvan shanker"
l_name="r"
print(f_name+" "+l_name)
# Out:
# dhuruvan shanker r

# %%
name="ash"
print(name*2)
# Out:
# ashash

# %%
len(name)
# Out:
# 3

# %%
name.upper()
# Out:
# 'ASH'

# %%
name.lower()
# Out:
# 'ash'

# %%
line="hi welcome you all"
line.capitalize()
# Out:
# 'Hi welcome you all'

# %%
line.title()
# Out:
# 'Hi Welcome You All'

# %%
sent="This is a dog"
print(sent)
# Out:
# This is a dog

# %%
s=sent.split()
print(s)
# Out:
# ['This', 'is', 'a', 'dog']

# %%
se=" ".join(s)
print(se)
len(se)
# Out:
# This is a dog
# 13

# %%
se="-".join(s)
print(se)
len(se)
# Out:
# This-is-a-dog
# 13

# %% [markdown]
# ### Indexing

# %%
s='abc'
print(s[0])
print(s[1])
print(s[2])
print(s[-1])
print(s[-2])
print(s[-3])
# Out:
# a
# b
# c
# c
# b
# a

# %%
sent
sent.index('o')
# Out:
# 11

# %% [markdown]
# ### Slicing

# %%
a="abcdefgh"
a[5:1:-2]
# Out:
# 'fd'

# %%
b=a[::]
b
# Out:
# 'abcdefgh'

# %%
a[-7:-2]
# Out:
# 'bcdef'

# %%
a[-2:-7:-2]
# Out:
# 'gec'

# %%
a[4:1:-1]
# Out:
# 'edc'

# %%
a[-6:-1:-2]
# Out:
# ''

# %%
a[::-2]
# Out:
# 'hfdb'

# %%
a[3::-2]
# Out:
# 'db'

# %%
s="hello"
print(s)
s='y'+s[1:len(s)]+'w'
print(s)
# Out:
# hello
# yellow

# %% [markdown]
# ### Nested List

# %%
n_l=[
    [1,2],
    ['a','b'],
    [True,False]
]
print(n_l)
len(n_l)
# Out:
# [[1, 2], ['a', 'b'], [True, False]]
# 3

# %%
n_l[0]
# Out:
# [1, 2]

# %%
n_l[-1][1]
# Out:
# False

# %%
l=[1,2,3]
l.insert(0,22)
print(l)
# Out:
# [22, 1, 2, 3]

# %%
l.append(4)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
l.pop()
print(l)
# Out:
# [1, 2, 3]

# %%
l.pop(2)
print(l)
# Out:
# [1, 2]

# %%
m=[3,4]
l.extend(m)
print(l)
# Out:
# [1, 2, 3, 4]

# %%
 l[:]
# Out:
# [1, 2, 3, 4]

# %%
l[::-1]
# Out:
# [4, 3, 2, 1]

# %%
l
# Out:
# [1, 2, 3, 4]

# %%
l.extend([5,6,4,4,7,8])
l
# Out:
# [1, 2, 3, 4, 5, 6, 4, 4, 7, 8, 5, 6, 4, 4, 7, 8]

# %%
l.count(4)
# Out:
# 5

# %%
l.reverse()
l
# Out:
# [8, 7, 4, 4, 6, 5, 8, 7, 4, 4, 6, 5, 4, 3, 2, 1]

# %%
n=l.copy()
m=l
print(l)
print(m)
print(n)
# Out:
# [8, 7, 4, 4, 6, 5, 8, 7, 4, 4, 6, 5, 4, 3, 2, 1]
# [8, 7, 4, 4, 6, 5, 8, 7, 4, 4, 6, 5, 4, 3, 2, 1]
# [8, 7, 4, 4, 6, 5, 8, 7, 4, 4, 6, 5, 4, 3, 2, 1]

# %%
l.index(6)
# Out:
# 4

# %%
l.remove(8)
l
# Out:
# [7, 4, 4, 6, 5, 7, 4, 4, 6, 5, 4, 3, 2, 1]

# %%
l.sort()
l
# Out:
# [1, 2, 3, 4, 4, 4, 4, 4, 5, 5, 6, 6, 7, 7]

# %%
print(min(l))
print(max(l))
# Out:
# 1
# 7

# %%
m=['a','b','c','z']
print(min(m))
print(max(m))
# Out:
# a
# z

# %%
a=['a','b']
b=['c','d','e']
c=a+b
print(c)
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
print(c*2)
# Out:
# ['a', 'b', 'c', 'd', 'e', 'a', 'b', 'c', 'd', 'e']

# %%
d=[1,2,3,4,5,6,7,4,8,9]
print(d.index(4,0,4))
# Out:
# 3

# %% [markdown]
# ### Tuples

# %%
t=1,2,3,4
print(t)
# Out:
# (1, 2, 3, 4)

# %%
t=(1,2,3,4)
t
# Out:
# (1, 2, 3, 4)

# %%
t[-1:-5:-1]
# Out:
# (4, 3, 2, 1)

# %%
t[::-1]
# Out:
# (4, 3, 2, 1)

# %%
t.count(4)
# Out:
# 1

# %%
t.index(2)
# Out:
# 1

# %%
len(t)
# Out:
# 4

# %%
t1=1,2,3
t2=4,5
t3=t1+t2
print(t3)
# Out:
# (1, 2, 3, 4, 5)

# %%
t2*2
# Out:
# (4, 5, 4, 5)

# %%
list(t2)
# Out:
# [4, 5]

# %%
type(t2)
# Out:
# tuple

# %%
type(list(t2))
# Out:
# list

# %% [markdown]
# ### Type Conversion

# %%
y=56.12
x=int(y)
print(x)
type(x)
# Out:
# 56
# int

# %%
y=56.52
x=int(y)
print(x)
type(x)
# Out:
# 56
# int

# %% [markdown]
# ### Flow Control

# %%
x=5
y=5
if x==y:
    print('x and y are equal')
# Out:
# x and y are equal

# %%
x=5
y=6
if x==y:
    print('x and y are equal')
else:
    print('They are not equal')
# Out:
# They are not equal

# %%
x=int(input("Enter the num1:"))
y=int(input("Enter the num2:"))
if x==y:
    print('x and y are equal')
elif x<y:
    print('x is smaller')
else:
    print('y is lesser')
# Out:
# Enter the num1: 22
# Enter the num2: 26
# x is smaller

# %%
x=int(input("Enter the day:"))
if x==1:
    print('sunday')
elif x==2:
    print('mon')
elif x==3:
    print('tue')
elif x==4:
    print('wed')
elif x==5:
    print('thur')
elif x==6:
    print('fri')
elif x==7:
    print('sat')
else:
    print('invalid input')
# Out:
# Enter the day: 8
# invalid input

# %%
a=int(input("Enter the num:"))
if a%2==0:
    print("even")    
else:
    print("odd")
# Out:
# Enter the num: 24
# even

# %%
age=int(input("Enter the age:"))
res='you can vote' if age>=18 else "you can't vote"
print(res)
# Out:
# Enter the age: 12
# you can't vote

# %%
x=int(input("Enter the num1"))
y=int(input("Enter the num2"))
z=int(input("Enter the num3"))
if x>y:
    if x>z:
        print('x is largest')
    else:
        print("z iis largest")
else:
    if y>z:
        print("y is largest")
    else:
        print("z is largest")
# Out:
# Enter the num1 2
# Enter the num2 3
# Enter the num3 4
# z is largest

# %%
x=int(input("Enter the num1:"))
y=int(input("Enter the num2:"))
z=int(input("Enter the num3:"))
if x>y and x>z:
    print("x is largest")
elif y>x and y>z:
    print("y is largest")
else:
    print("z is largest")
# Out:
# Enter the num1: 2
# Enter the num2: 3
# Enter the num3: 4
# z is largest

# %%
a,b,c=10,22,14
largest=a if(a>b and a>c) else(b if b>c else c)
print(largest)
# Out:
# 22

# %%
age=int(input("Enter the age:"))
if age<13:
    print("kid")
elif age>=13 and age<=19:
    print("Teenager")
elif age>=20 and age<=40:
    print("Adult")
elif age>40 and age<=55:
    print("Middle age")
else:
    print("Senior citizen")
# Out:
# Enter the age: 45
# Middle age

# %% [markdown]
# # Round Built-in  function

# %%
round(2.5)
# Out:
# 2

# %%
round(2.6)
# Out:
# 3

# %%
round(2.4)
# Out:
# 2

# %%
round(3.5)
# Out:
# 4

# %%
round(3.4)
# Out:
# 3

# %%
round(3.6)
# Out:
# 4

# %%
round(4.5)
# Out:
# 4

# %%
round(4.4)
# Out:
# 4

# %%
p=int(input("Enter the principal amount:"))
r=int(input("Enter the rate:"))
t=int(input("Enter the time:"))
si=(p*r*t)/100
print("Simple Interest:",si)
# Out:
# Enter the principal amount: 10000
# Enter the rate: 6
# Enter the time: 2
# Simple Interest: 1200.0

# %%
p=float(input("Enter the principal amount:"))
r=float(input("Enter the rate:"))
t=float(input("Enter the time:"))
n=float(input("Enter the no:times:"))
ci=p*((1+(r/n))**(n*t))-p
print("Compound Interest:",round(ci,2))
# Out:
# Enter the principal amount: 20000
# Enter the rate: 0.1
# Enter the time: 3
# Enter the no:times: 2
# Compound Interest: 6801.91

# %%
r=int(input("Enter the radius:"))
area=(22/7)*r*r
print(area>50)
# Out:
# Enter the radius: 3
# False

# %%
name=["Ash","Merena","Misty","Brock"]
print(max(name))
print(min(name))
# Out:
# Misty
# Ash
